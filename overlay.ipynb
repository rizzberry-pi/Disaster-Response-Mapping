# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from osgeo import gdal
import rasterio

# %%
shapefile1 = gpd.read_file("test.shp")
shapefile2 = gpd.read_file("test2.shp")
singapore = rasterio.open("sgboleh.tif")
shapefile1.columns
shapefile2.plot()


shapefile1.plot(color="brown")
# Out:
# <Axes: >

# %%
f,ax = plt.subplots()
rasterio.plot.show(singapore.read(), transform = singapore.transform)
shapefile2.plot()
# Out:
# <Axes: >
