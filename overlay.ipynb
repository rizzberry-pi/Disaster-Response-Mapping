# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from osgeo import gdal
import rasterio

# %%
shapefile1 = gpd.read_file("test.shp")
shapefile2 = gpd.read_file("test2.shp")
singapore = rasterio.open("sgboleh.tif")
shapefile1.plot()
shapefile2.plot()

shapefile2
# Out:
#    id                                           geometry
# 0   0  LINESTRING (103.96644 1.38565, 103.96761 1.382...

# %%
gdal.RasterizeOptions(singapore,shapefile1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\beben\OneDrive\Bureau\Road-Detection\overlay.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/beben/OneDrive/Bureau/Road-Detection/overlay.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> gdal.RasterizeOptions(singapore,shapefile1)
#
# File c:\Users\beben\anaconda3\Lib\site-packages\osgeo\gdal.py:1441, in RasterizeOptions(options, format, outputType, creationOptions, noData, initValues, outputBounds, outputSRS, transformerOptions, width, height, xRes, yRes, targetAlignedPixels, bands, inverse, allTouched, burnValues, attribute, useZ, layers, SQLStatement, SQLDialect, where, optim, add, callback, callback_data)
#    1439 new_options = options
#    1440 if format is not None:
# -> 1441     new_options += ['-of', format]
#    1442 if outputType != gdalconst.GDT_Unknown:
#    1443     new_options += ['-ot', GetDataTypeName(outputType)]
#
# TypeError: unsupported operand type(s) for +=: 'DatasetReader' and 'list'
